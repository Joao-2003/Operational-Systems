# %% [markdown]
# <a href="https://colab.research.google.com/github/Joao-2003/Operational-Systems-/blob/main/EstadosProcessos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Enumeração para os estados do processo para maior clareza
class EstadoProcesso:
    PRONTO = "PRONTO"
    EXECUTANDO = "EXECUTANDO"
    BLOQUEADO = "BLOQUEADO"
    TERMINADO = "TERMINADO"

class Processo:
    """
    Representa o Bloco de Controle de Processo (PCB).
    Armazena todos os atributos e o estado de um único processo.
    """
    def __init__(self, pid, tempo_total_execucao):
        self.pid = pid
        self.tempo_total_execucao = tempo_total_execucao
        self.tp = 0  # Tempo de Processamento (total de ciclos executados)
        self.cp = 1  # Contador de Programa (TP + 1)
        self.ep = EstadoProcesso.PRONTO  # Estado do Processo
        self.nes = 0 # Número de vezes que realizou E/S
        self.n_cpu = 0 # Número de vezes que usou a CPU

    def __str__(self):
        """Representação em string para fácil visualização."""
        return (f"PID: {self.pid} | TP: {self.tp}/{self.tempo_total_execucao} | "
                f"CP: {self.cp} | Estado: {self.ep} | E/S: {self.nes} | "
                f"N_CPU: {self.n_cpu}")

    def executar_ciclo(self):
        """Simula a execução de um único ciclo de CPU."""
        if self.tp < self.tempo_total_execucao:
            self.tp += 1
            self.cp = self.tp + 1

    def is_terminado(self):
        """Verifica se o processo concluiu sua execução."""
        return self.tp == self.tempo_total_execucao

# %%
import time

class Escalonador:
    """
    Implementa a lógica do escalonador Sequencial Estático e o ciclo principal.
    """
    def __init__(self, processos, quantum, prob_es, prob_desbloqueio):
        self.lista_de_processos = processos # Lista estática e ordenada por PID
        self.quantum = quantum
        self.prob_es = prob_es
        self.prob_desbloqueio = prob_desbloqueio
        self.ciclo_global = 0
        self.log_file = "Tabela_de_Processos.txt"

        # Inicializa o arquivo de log com um cabeçalho
        with open(self.log_file, 'w') as f:
            f.write("CicloGlobal,PID,TP,CP,EstadoAnterior,EstadoNovo,NES,N_CPU\n")

    def _log_troca_contexto(self, processo, estado_anterior, estado_novo):
        """
        Registra a troca de contexto no console e no arquivo de log.
        """
        print(f"** Troca de Contexto no ciclo {self.ciclo_global} **")
        print(f"   Processo {processo.pid}: {estado_anterior} >>> {estado_novo}")
        print(f"   Estado salvo: {processo}\n")

        with open(self.log_file, 'a') as f:
            log_entry = (f"{self.ciclo_global},{processo.pid},{processo.tp},{processo.cp},"
                         f"{estado_anterior},{estado_novo},{processo.nes},{processo.n_cpu}\n")
            f.write(log_entry)

    def simular(self):
        """
        Executa o ciclo principal da simulação até que todos os processos terminem.
        """
        print(">>> INÍCIO DA SIMULAÇÃO <<<\n")

        num_processos_terminados = 0
        total_processos = len(self.lista_de_processos)

        while num_processos_terminados < total_processos:
            # Itera sobre a lista de processos em ordem fixa (0 a 9)
            for processo in self.lista_de_processos:

                # 1. Ignora processos já terminados
                if processo.ep == EstadoProcesso.TERMINADO:
                    continue

                # 2. Lida com processos bloqueados
                if processo.ep == EstadoProcesso.BLOQUEADO:
                    if random.random() < self.prob_desbloqueio:
                        processo.ep = EstadoProcesso.PRONTO
                        print(f"--- Evento no ciclo {self.ciclo_global}: Processo {processo.pid} desbloqueado. Agora está PRONTO.\n")
                        self.ciclo_global += 1
                        continue
                    # Se não desbloquear, simplesmente passa para o próximo
                    continue

                # 3. Lida com processos prontos para executar
                if processo.ep == EstadoProcesso.PRONTO:
                    processo.ep = EstadoProcesso.EXECUTANDO
                    processo.n_cpu += 1
                    print(f"--- Ciclo {self.ciclo_global}: Despachando processo {processo.pid} para a CPU (N_CPU: {processo.n_cpu}).\n")

                    interrompido = False
                    for _ in range(self.quantum):
                        self.ciclo_global += 1
                        processo.executar_ciclo()

                        if processo.is_terminado():
                            estado_anterior = processo.ep
                            processo.ep = EstadoProcesso.TERMINADO
                            print("="*50)
                            print(f"PROCESSO {processo.pid} TERMINOU NO CICLO {self.ciclo_global}")
                            print(f"Estado Final: {processo}")
                            print("="*50 + "\n")
                            num_processos_terminados += 1
                            interrompido = True
                            break

                        if random.random() < self.prob_es:
                            estado_anterior = processo.ep
                            processo.ep = EstadoProcesso.BLOQUEADO
                            processo.nes += 1
                            self._log_troca_contexto(processo, estado_anterior, EstadoProcesso.BLOQUEADO)
                            interrompido = True
                            break

                    if not interrompido:
                        estado_anterior = processo.ep
                        processo.ep = EstadoProcesso.PRONTO
                        self._log_troca_contexto(processo, estado_anterior, EstadoProcesso.PRONTO)


        print(">>> FIM DA SIMULAÇÃO: Todos os processos foram concluídos. <<<\n")

# %%
# main.py

if __name__ == "__main__":
    # Definição dos tempos de execução para cada PID
    tempos_de_execucao = {
        0: 10000, 1: 5000, 2: 7000, 3: 3000, 4: 3000,
        5: 8000, 6: 2000, 7: 5000, 8: 4000, 9: 10000
    }

    # Criação da lista inicial de processos
    lista_de_processos = []
    for pid, tempo in tempos_de_execucao.items():
        lista_de_processos.append(Processo(pid=pid, tempo_total_execucao=tempo))

    print("Estado inicial dos processos:")
    for p in lista_de_processos:
        print(p)
    print("\n" + "-"*60 + "\n")

    # Parâmetros da simulação
    QUANTUM = 1000
    PROBABILIDADE_ES = 0.01  # 1%
    PROBABILIDADE_DESBLOQUEIO = 0.30 # 30%

    # Instanciação e execução do escalonador
    escalonador = Escalonador(
        processos=lista_de_processos,
        quantum=QUANTUM,
        prob_es=PROBABILIDADE_ES,
        prob_desbloqueio=PROBABILIDADE_DESBLOQUEIO
    )

    escalonador.simular()
# Out:
# Estado inicial dos processos:
# PID: 0 | TP: 0/10000 | CP: 1 | Estado: PRONTO | E/S: 0 | N_CPU: 0
# PID: 1 | TP: 0/5000 | CP: 1 | Estado: PRONTO | E/S: 0 | N_CPU: 0
# PID: 2 | TP: 0/7000 | CP: 1 | Estado: PRONTO | E/S: 0 | N_CPU: 0
# PID: 3 | TP: 0/3000 | CP: 1 | Estado: PRONTO | E/S: 0 | N_CPU: 0
# PID: 4 | TP: 0/3000 | CP: 1 | Estado: PRONTO | E/S: 0 | N_CPU: 0
# PID: 5 | TP: 0/8000 | CP: 1 | Estado: PRONTO | E/S: 0 | N_CPU: 0
# PID: 6 | TP: 0/2000 | CP: 1 | Estado: PRONTO | E/S: 0 | N_CPU: 0
# PID: 7 | TP: 0/5000 | CP: 1 | Estado: PRONTO | E/S: 0 | N_CPU: 0
# PID: 8 | TP: 0/4000 | CP: 1 | Estado: PRONTO | E/S: 0 | N_CPU: 0
# PID: 9 | TP: 0/10000 | CP: 1 | Estado: PRONTO | E/S: 0 | N_CPU: 0
#
# ------------------------------------------------------------
#
# >>> INÍCIO DA SIMULAÇÃO <<<
#
# --- Ciclo 0: Despachando processo 0 para a CPU (N_CPU: 1).
#
# ** Troca de Contexto no ciclo 15 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 15/10000 | CP: 16 | Estado: BLOQUEADO | E/S: 1 | N_CPU: 1
#
# --- Ciclo 15: Despachando processo 1 para a CPU (N_CPU: 1).
#
# ** Troca de Contexto no ciclo 133 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 118/5000 | CP: 119 | Estado: BLOQUEADO | E/S: 1 | N_CPU: 1
#
# --- Ciclo 133: Despachando processo 2 para a CPU (N_CPU: 1).
#
# ** Troca de Contexto no ciclo 290 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 157/7000 | CP: 158 | Estado: BLOQUEADO | E/S: 1 | N_CPU: 1
#
# --- Ciclo 290: Despachando processo 3 para a CPU (N_CPU: 1).
#
# ** Troca de Contexto no ciclo 329 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 39/3000 | CP: 40 | Estado: BLOQUEADO | E/S: 1 | N_CPU: 1
#
# --- Ciclo 329: Despachando processo 4 para a CPU (N_CPU: 1).
#
# ** Troca de Contexto no ciclo 430 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 101/3000 | CP: 102 | Estado: BLOQUEADO | E/S: 1 | N_CPU: 1
#
# --- Ciclo 430: Despachando processo 5 para a CPU (N_CPU: 1).
#
# ** Troca de Contexto no ciclo 464 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 34/8000 | CP: 35 | Estado: BLOQUEADO | E/S: 1 | N_CPU: 1
#
# --- Ciclo 464: Despachando processo 6 para a CPU (N_CPU: 1).
#
# ** Troca de Contexto no ciclo 543 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 79/2000 | CP: 80 | Estado: BLOQUEADO | E/S: 1 | N_CPU: 1
#
# --- Ciclo 543: Despachando processo 7 para a CPU (N_CPU: 1).
#
# ** Troca de Contexto no ciclo 730 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 187/5000 | CP: 188 | Estado: BLOQUEADO | E/S: 1 | N_CPU: 1
#
# --- Ciclo 730: Despachando processo 8 para a CPU (N_CPU: 1).
#
# ** Troca de Contexto no ciclo 780 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 50/4000 | CP: 51 | Estado: BLOQUEADO | E/S: 1 | N_CPU: 1
#
# --- Ciclo 780: Despachando processo 9 para a CPU (N_CPU: 1).
#
# ** Troca de Contexto no ciclo 888 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 108/10000 | CP: 109 | Estado: BLOQUEADO | E/S: 1 | N_CPU: 1
#
# --- Evento no ciclo 888: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 889: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 890: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 891: Despachando processo 1 para a CPU (N_CPU: 2).
#
# ** Troca de Contexto no ciclo 893 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 120/5000 | CP: 121 | Estado: BLOQUEADO | E/S: 2 | N_CPU: 2
#
# --- Ciclo 893: Despachando processo 4 para a CPU (N_CPU: 2).
#
# ** Troca de Contexto no ciclo 1166 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 374/3000 | CP: 375 | Estado: BLOQUEADO | E/S: 2 | N_CPU: 2
#
# --- Ciclo 1166: Despachando processo 7 para a CPU (N_CPU: 2).
#
# ** Troca de Contexto no ciclo 1181 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 202/5000 | CP: 203 | Estado: BLOQUEADO | E/S: 2 | N_CPU: 2
#
# --- Evento no ciclo 1181: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 1182: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 1183: Despachando processo 0 para a CPU (N_CPU: 2).
#
# ** Troca de Contexto no ciclo 1225 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 57/10000 | CP: 58 | Estado: BLOQUEADO | E/S: 2 | N_CPU: 2
#
# --- Ciclo 1225: Despachando processo 2 para a CPU (N_CPU: 2).
#
# ** Troca de Contexto no ciclo 1262 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 194/7000 | CP: 195 | Estado: BLOQUEADO | E/S: 2 | N_CPU: 2
#
# --- Evento no ciclo 1262: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 1263: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 1264: Despachando processo 7 para a CPU (N_CPU: 3).
#
# ** Troca de Contexto no ciclo 1362 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 300/5000 | CP: 301 | Estado: BLOQUEADO | E/S: 3 | N_CPU: 3
#
# --- Evento no ciclo 1362: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 1363: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 1364: Despachando processo 6 para a CPU (N_CPU: 2).
#
# ** Troca de Contexto no ciclo 1396 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 111/2000 | CP: 112 | Estado: BLOQUEADO | E/S: 2 | N_CPU: 2
#
# --- Ciclo 1396: Despachando processo 8 para a CPU (N_CPU: 2).
#
# ** Troca de Contexto no ciclo 1428 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 82/4000 | CP: 83 | Estado: BLOQUEADO | E/S: 2 | N_CPU: 2
#
# --- Evento no ciclo 1428: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 1429: Despachando processo 0 para a CPU (N_CPU: 3).
#
# ** Troca de Contexto no ciclo 1491 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 119/10000 | CP: 120 | Estado: BLOQUEADO | E/S: 3 | N_CPU: 3
#
# --- Evento no ciclo 1491: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 1492: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 1493: Despachando processo 9 para a CPU (N_CPU: 2).
#
# ** Troca de Contexto no ciclo 1616 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 231/10000 | CP: 232 | Estado: BLOQUEADO | E/S: 2 | N_CPU: 2
#
# --- Ciclo 1616: Despachando processo 2 para a CPU (N_CPU: 3).
#
# ** Troca de Contexto no ciclo 1633 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 211/7000 | CP: 212 | Estado: BLOQUEADO | E/S: 3 | N_CPU: 3
#
# --- Evento no ciclo 1633: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 1634: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 1635: Despachando processo 8 para a CPU (N_CPU: 3).
#
# ** Troca de Contexto no ciclo 1691 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 138/4000 | CP: 139 | Estado: BLOQUEADO | E/S: 3 | N_CPU: 3
#
# --- Evento no ciclo 1691: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 1692: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 1693: Despachando processo 4 para a CPU (N_CPU: 3).
#
# ** Troca de Contexto no ciclo 1935 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 616/3000 | CP: 617 | Estado: BLOQUEADO | E/S: 3 | N_CPU: 3
#
# --- Ciclo 1935: Despachando processo 6 para a CPU (N_CPU: 3).
#
# ** Troca de Contexto no ciclo 1939 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 115/2000 | CP: 116 | Estado: BLOQUEADO | E/S: 3 | N_CPU: 3
#
# --- Ciclo 1939: Despachando processo 0 para a CPU (N_CPU: 4).
#
# ** Troca de Contexto no ciclo 1983 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 163/10000 | CP: 164 | Estado: BLOQUEADO | E/S: 4 | N_CPU: 4
#
# --- Evento no ciclo 1983: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 1984: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 1985: Despachando processo 3 para a CPU (N_CPU: 2).
#
# ** Troca de Contexto no ciclo 2172 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 226/3000 | CP: 227 | Estado: BLOQUEADO | E/S: 2 | N_CPU: 2
#
# --- Evento no ciclo 2172: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 2173: Despachando processo 1 para a CPU (N_CPU: 3).
#
# ** Troca de Contexto no ciclo 2293 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 240/5000 | CP: 241 | Estado: BLOQUEADO | E/S: 3 | N_CPU: 3
#
# --- Ciclo 2293: Despachando processo 2 para a CPU (N_CPU: 4).
#
# ** Troca de Contexto no ciclo 2305 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 223/7000 | CP: 224 | Estado: BLOQUEADO | E/S: 4 | N_CPU: 4
#
# --- Ciclo 2305: Despachando processo 6 para a CPU (N_CPU: 4).
#
# ** Troca de Contexto no ciclo 2383 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 193/2000 | CP: 194 | Estado: BLOQUEADO | E/S: 4 | N_CPU: 4
#
# --- Evento no ciclo 2383: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 2384: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 2385: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 2386: Despachando processo 2 para a CPU (N_CPU: 5).
#
# ** Troca de Contexto no ciclo 2390 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 227/7000 | CP: 228 | Estado: BLOQUEADO | E/S: 5 | N_CPU: 5
#
# --- Ciclo 2390: Despachando processo 3 para a CPU (N_CPU: 3).
#
# ** Troca de Contexto no ciclo 2438 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 274/3000 | CP: 275 | Estado: BLOQUEADO | E/S: 3 | N_CPU: 3
#
# --- Evento no ciclo 2438: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 2439: Despachando processo 8 para a CPU (N_CPU: 4).
#
# ** Troca de Contexto no ciclo 2453 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 152/4000 | CP: 153 | Estado: BLOQUEADO | E/S: 4 | N_CPU: 4
#
# --- Evento no ciclo 2453: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 2454: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 2455: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 2456: Despachando processo 6 para a CPU (N_CPU: 5).
#
# ** Troca de Contexto no ciclo 2464 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 201/2000 | CP: 202 | Estado: BLOQUEADO | E/S: 5 | N_CPU: 5
#
# --- Ciclo 2464: Despachando processo 1 para a CPU (N_CPU: 4).
#
# ** Troca de Contexto no ciclo 2531 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 307/5000 | CP: 308 | Estado: BLOQUEADO | E/S: 4 | N_CPU: 4
#
# --- Ciclo 2531: Despachando processo 2 para a CPU (N_CPU: 6).
#
# ** Troca de Contexto no ciclo 2644 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 340/7000 | CP: 341 | Estado: BLOQUEADO | E/S: 6 | N_CPU: 6
#
# --- Ciclo 2644: Despachando processo 5 para a CPU (N_CPU: 2).
#
# ** Troca de Contexto no ciclo 2813 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 203/8000 | CP: 204 | Estado: BLOQUEADO | E/S: 2 | N_CPU: 2
#
# --- Evento no ciclo 2813: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 2814: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 2815: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 2816: Despachando processo 1 para a CPU (N_CPU: 5).
#
# ** Troca de Contexto no ciclo 2914 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 405/5000 | CP: 406 | Estado: BLOQUEADO | E/S: 5 | N_CPU: 5
#
# --- Ciclo 2914: Despachando processo 3 para a CPU (N_CPU: 4).
#
# ** Troca de Contexto no ciclo 2939 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 299/3000 | CP: 300 | Estado: BLOQUEADO | E/S: 4 | N_CPU: 4
#
# --- Evento no ciclo 2939: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 2940: Despachando processo 5 para a CPU (N_CPU: 3).
#
# ** Troca de Contexto no ciclo 3221 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 484/8000 | CP: 485 | Estado: BLOQUEADO | E/S: 3 | N_CPU: 3
#
# --- Evento no ciclo 3221: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 3222: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 3223: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 3224: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 3225: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 3226: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 3227: Despachando processo 4 para a CPU (N_CPU: 4).
#
# ** Troca de Contexto no ciclo 3465 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 854/3000 | CP: 855 | Estado: BLOQUEADO | E/S: 4 | N_CPU: 4
#
# --- Evento no ciclo 3465: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 3466: Despachando processo 6 para a CPU (N_CPU: 6).
#
# ** Troca de Contexto no ciclo 3480 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 215/2000 | CP: 216 | Estado: BLOQUEADO | E/S: 6 | N_CPU: 6
#
# --- Ciclo 3480: Despachando processo 8 para a CPU (N_CPU: 5).
#
# ** Troca de Contexto no ciclo 3491 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 163/4000 | CP: 164 | Estado: BLOQUEADO | E/S: 5 | N_CPU: 5
#
# --- Ciclo 3491: Despachando processo 9 para a CPU (N_CPU: 3).
#
# ** Troca de Contexto no ciclo 3751 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 491/10000 | CP: 492 | Estado: BLOQUEADO | E/S: 3 | N_CPU: 3
#
# --- Ciclo 3751: Despachando processo 0 para a CPU (N_CPU: 5).
#
# ** Troca de Contexto no ciclo 4260 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 672/10000 | CP: 673 | Estado: BLOQUEADO | E/S: 5 | N_CPU: 5
#
# --- Ciclo 4260: Despachando processo 1 para a CPU (N_CPU: 6).
#
# ** Troca de Contexto no ciclo 4371 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 516/5000 | CP: 517 | Estado: BLOQUEADO | E/S: 6 | N_CPU: 6
#
# --- Ciclo 4371: Despachando processo 2 para a CPU (N_CPU: 7).
#
# ** Troca de Contexto no ciclo 4575 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 544/7000 | CP: 545 | Estado: BLOQUEADO | E/S: 7 | N_CPU: 7
#
# --- Evento no ciclo 4575: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 4576: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 4577: Despachando processo 5 para a CPU (N_CPU: 4).
#
# ** Troca de Contexto no ciclo 4836 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 743/8000 | CP: 744 | Estado: BLOQUEADO | E/S: 4 | N_CPU: 4
#
# --- Evento no ciclo 4836: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 4837: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 4838: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 4839: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 4840: Despachando processo 3 para a CPU (N_CPU: 5).
#
# ** Troca de Contexto no ciclo 4867 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 326/3000 | CP: 327 | Estado: BLOQUEADO | E/S: 5 | N_CPU: 5
#
# --- Ciclo 4867: Despachando processo 4 para a CPU (N_CPU: 5).
#
# ** Troca de Contexto no ciclo 4907 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 894/3000 | CP: 895 | Estado: BLOQUEADO | E/S: 5 | N_CPU: 5
#
# --- Evento no ciclo 4907: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 4908: Despachando processo 7 para a CPU (N_CPU: 4).
#
# ** Troca de Contexto no ciclo 4969 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 361/5000 | CP: 362 | Estado: BLOQUEADO | E/S: 4 | N_CPU: 4
#
# --- Ciclo 4969: Despachando processo 8 para a CPU (N_CPU: 6).
#
# ** Troca de Contexto no ciclo 5046 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 240/4000 | CP: 241 | Estado: BLOQUEADO | E/S: 6 | N_CPU: 6
#
# --- Ciclo 5046: Despachando processo 9 para a CPU (N_CPU: 4).
#
# ** Troca de Contexto no ciclo 5193 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 638/10000 | CP: 639 | Estado: BLOQUEADO | E/S: 4 | N_CPU: 4
#
# --- Evento no ciclo 5193: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 5194: Despachando processo 2 para a CPU (N_CPU: 8).
#
# ** Troca de Contexto no ciclo 5299 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 649/7000 | CP: 650 | Estado: BLOQUEADO | E/S: 8 | N_CPU: 8
#
# --- Evento no ciclo 5299: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 5300: Despachando processo 6 para a CPU (N_CPU: 7).
#
# ** Troca de Contexto no ciclo 5440 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 355/2000 | CP: 356 | Estado: BLOQUEADO | E/S: 7 | N_CPU: 7
#
# --- Evento no ciclo 5440: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 5441: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 5442: Despachando processo 1 para a CPU (N_CPU: 7).
#
# ** Troca de Contexto no ciclo 5623 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 697/5000 | CP: 698 | Estado: BLOQUEADO | E/S: 7 | N_CPU: 7
#
# --- Evento no ciclo 5623: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 5624: Despachando processo 5 para a CPU (N_CPU: 5).
#
# ** Troca de Contexto no ciclo 5644 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 763/8000 | CP: 764 | Estado: BLOQUEADO | E/S: 5 | N_CPU: 5
#
# --- Evento no ciclo 5644: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 5645: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 5646: Despachando processo 9 para a CPU (N_CPU: 5).
#
# ** Troca de Contexto no ciclo 5719 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 711/10000 | CP: 712 | Estado: BLOQUEADO | E/S: 5 | N_CPU: 5
#
# --- Ciclo 5719: Despachando processo 0 para a CPU (N_CPU: 6).
#
# ** Troca de Contexto no ciclo 5854 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 807/10000 | CP: 808 | Estado: BLOQUEADO | E/S: 6 | N_CPU: 6
#
# --- Evento no ciclo 5854: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 5855: Despachando processo 4 para a CPU (N_CPU: 6).
#
# ** Troca de Contexto no ciclo 5888 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 927/3000 | CP: 928 | Estado: BLOQUEADO | E/S: 6 | N_CPU: 6
#
# --- Ciclo 5888: Despachando processo 6 para a CPU (N_CPU: 8).
#
# ** Troca de Contexto no ciclo 5968 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 435/2000 | CP: 436 | Estado: BLOQUEADO | E/S: 8 | N_CPU: 8
#
# --- Ciclo 5968: Despachando processo 7 para a CPU (N_CPU: 5).
#
# ** Troca de Contexto no ciclo 6046 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 439/5000 | CP: 440 | Estado: BLOQUEADO | E/S: 5 | N_CPU: 5
#
# --- Ciclo 6046: Despachando processo 1 para a CPU (N_CPU: 8).
#
# ** Troca de Contexto no ciclo 6290 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 941/5000 | CP: 942 | Estado: BLOQUEADO | E/S: 8 | N_CPU: 8
#
# --- Evento no ciclo 6290: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 6291: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 6292: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 6293: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 6294: Despachando processo 5 para a CPU (N_CPU: 6).
#
# ** Troca de Contexto no ciclo 6439 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 908/8000 | CP: 909 | Estado: BLOQUEADO | E/S: 6 | N_CPU: 6
#
# --- Ciclo 6439: Despachando processo 7 para a CPU (N_CPU: 6).
#
# ** Troca de Contexto no ciclo 6489 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 489/5000 | CP: 490 | Estado: BLOQUEADO | E/S: 6 | N_CPU: 6
#
# --- Ciclo 6489: Despachando processo 8 para a CPU (N_CPU: 7).
#
# ** Troca de Contexto no ciclo 6503 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 254/4000 | CP: 255 | Estado: BLOQUEADO | E/S: 7 | N_CPU: 7
#
# --- Ciclo 6503: Despachando processo 1 para a CPU (N_CPU: 9).
#
# ** Troca de Contexto no ciclo 6575 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 1013/5000 | CP: 1014 | Estado: BLOQUEADO | E/S: 9 | N_CPU: 9
#
# --- Evento no ciclo 6575: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 6576: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 6577: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 6578: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 6579: Despachando processo 3 para a CPU (N_CPU: 6).
#
# ** Troca de Contexto no ciclo 6665 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 412/3000 | CP: 413 | Estado: BLOQUEADO | E/S: 6 | N_CPU: 6
#
# --- Evento no ciclo 6665: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 6666: Despachando processo 5 para a CPU (N_CPU: 7).
#
# ** Troca de Contexto no ciclo 6694 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 936/8000 | CP: 937 | Estado: BLOQUEADO | E/S: 7 | N_CPU: 7
#
# --- Ciclo 6694: Despachando processo 8 para a CPU (N_CPU: 8).
#
# ** Troca de Contexto no ciclo 6843 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 403/4000 | CP: 404 | Estado: BLOQUEADO | E/S: 8 | N_CPU: 8
#
# --- Ciclo 6843: Despachando processo 9 para a CPU (N_CPU: 6).
#
# ** Troca de Contexto no ciclo 6881 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 749/10000 | CP: 750 | Estado: BLOQUEADO | E/S: 6 | N_CPU: 6
#
# --- Evento no ciclo 6881: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 6882: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 6883: Despachando processo 4 para a CPU (N_CPU: 7).
#
# ** Troca de Contexto no ciclo 7392 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 1436/3000 | CP: 1437 | Estado: BLOQUEADO | E/S: 7 | N_CPU: 7
#
# --- Ciclo 7392: Despachando processo 0 para a CPU (N_CPU: 7).
#
# ** Troca de Contexto no ciclo 7406 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 821/10000 | CP: 822 | Estado: BLOQUEADO | E/S: 7 | N_CPU: 7
#
# --- Evento no ciclo 7406: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 7407: Despachando processo 3 para a CPU (N_CPU: 7).
#
# ** Troca de Contexto no ciclo 7463 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 468/3000 | CP: 469 | Estado: BLOQUEADO | E/S: 7 | N_CPU: 7
#
# --- Evento no ciclo 7463: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 7464: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 7465: Despachando processo 2 para a CPU (N_CPU: 9).
#
# ** Troca de Contexto no ciclo 7645 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 829/7000 | CP: 830 | Estado: BLOQUEADO | E/S: 9 | N_CPU: 9
#
# --- Ciclo 7645: Despachando processo 4 para a CPU (N_CPU: 8).
#
# ** Troca de Contexto no ciclo 7865 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 1656/3000 | CP: 1657 | Estado: BLOQUEADO | E/S: 8 | N_CPU: 8
#
# --- Ciclo 7865: Despachando processo 6 para a CPU (N_CPU: 9).
#
# ** Troca de Contexto no ciclo 7995 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 565/2000 | CP: 566 | Estado: BLOQUEADO | E/S: 9 | N_CPU: 9
#
# --- Evento no ciclo 7995: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 7996: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 7997: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 7998: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 7999: Despachando processo 8 para a CPU (N_CPU: 9).
#
# ** Troca de Contexto no ciclo 8251 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 655/4000 | CP: 656 | Estado: BLOQUEADO | E/S: 9 | N_CPU: 9
#
# --- Ciclo 8251: Despachando processo 9 para a CPU (N_CPU: 7).
#
# ** Troca de Contexto no ciclo 8424 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 922/10000 | CP: 923 | Estado: BLOQUEADO | E/S: 7 | N_CPU: 7
#
# --- Ciclo 8424: Despachando processo 0 para a CPU (N_CPU: 8).
#
# ** Troca de Contexto no ciclo 8704 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 1101/10000 | CP: 1102 | Estado: BLOQUEADO | E/S: 8 | N_CPU: 8
#
# --- Ciclo 8704: Despachando processo 1 para a CPU (N_CPU: 10).
#
# ** Troca de Contexto no ciclo 8763 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 1072/5000 | CP: 1073 | Estado: BLOQUEADO | E/S: 10 | N_CPU: 10
#
# --- Evento no ciclo 8763: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 8764: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 8765: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 8766: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 8767: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 8768: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 8769: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 8770: Despachando processo 9 para a CPU (N_CPU: 8).
#
# ** Troca de Contexto no ciclo 8953 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 1105/10000 | CP: 1106 | Estado: BLOQUEADO | E/S: 8 | N_CPU: 8
#
# --- Evento no ciclo 8953: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 8954: Despachando processo 1 para a CPU (N_CPU: 11).
#
# ** Troca de Contexto no ciclo 9246 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 1364/5000 | CP: 1365 | Estado: BLOQUEADO | E/S: 11 | N_CPU: 11
#
# --- Ciclo 9246: Despachando processo 2 para a CPU (N_CPU: 10).
#
# ** Troca de Contexto no ciclo 9250 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 833/7000 | CP: 834 | Estado: BLOQUEADO | E/S: 10 | N_CPU: 10
#
# --- Ciclo 9250: Despachando processo 3 para a CPU (N_CPU: 8).
#
# ** Troca de Contexto no ciclo 9390 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 608/3000 | CP: 609 | Estado: BLOQUEADO | E/S: 8 | N_CPU: 8
#
# --- Evento no ciclo 9390: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 9391: Despachando processo 6 para a CPU (N_CPU: 10).
#
# ** Troca de Contexto no ciclo 9470 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 644/2000 | CP: 645 | Estado: BLOQUEADO | E/S: 10 | N_CPU: 10
#
# --- Ciclo 9470: Despachando processo 7 para a CPU (N_CPU: 7).
#
# ** Troca de Contexto no ciclo 9493 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 512/5000 | CP: 513 | Estado: BLOQUEADO | E/S: 7 | N_CPU: 7
#
# --- Ciclo 9493: Despachando processo 8 para a CPU (N_CPU: 10).
#
# ** Troca de Contexto no ciclo 9502 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 664/4000 | CP: 665 | Estado: BLOQUEADO | E/S: 10 | N_CPU: 10
#
# --- Ciclo 9502: Despachando processo 0 para a CPU (N_CPU: 9).
#
# ** Troca de Contexto no ciclo 9576 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 1175/10000 | CP: 1176 | Estado: BLOQUEADO | E/S: 9 | N_CPU: 9
#
# --- Ciclo 9576: Despachando processo 4 para a CPU (N_CPU: 9).
#
# ** Troca de Contexto no ciclo 9643 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 1723/3000 | CP: 1724 | Estado: BLOQUEADO | E/S: 9 | N_CPU: 9
#
# --- Evento no ciclo 9643: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 9644: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 9645: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 9646: Despachando processo 5 para a CPU (N_CPU: 8).
#
# ** Troca de Contexto no ciclo 9671 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 961/8000 | CP: 962 | Estado: BLOQUEADO | E/S: 8 | N_CPU: 8
#
# --- Ciclo 9671: Despachando processo 6 para a CPU (N_CPU: 11).
#
# ** Troca de Contexto no ciclo 9811 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 784/2000 | CP: 785 | Estado: BLOQUEADO | E/S: 11 | N_CPU: 11
#
# --- Evento no ciclo 9811: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 9812: Despachando processo 4 para a CPU (N_CPU: 10).
#
# ** Troca de Contexto no ciclo 9863 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 1774/3000 | CP: 1775 | Estado: BLOQUEADO | E/S: 10 | N_CPU: 10
#
# --- Ciclo 9863: Despachando processo 8 para a CPU (N_CPU: 11).
#
# ** Troca de Contexto no ciclo 10131 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 932/4000 | CP: 933 | Estado: BLOQUEADO | E/S: 11 | N_CPU: 11
#
# --- Evento no ciclo 10131: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 10132: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 10133: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 10134: Despachando processo 9 para a CPU (N_CPU: 9).
#
# ** Troca de Contexto no ciclo 10186 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 1157/10000 | CP: 1158 | Estado: BLOQUEADO | E/S: 9 | N_CPU: 9
#
# --- Ciclo 10186: Despachando processo 0 para a CPU (N_CPU: 10).
#
# ** Troca de Contexto no ciclo 10322 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 1311/10000 | CP: 1312 | Estado: BLOQUEADO | E/S: 10 | N_CPU: 10
#
# --- Evento no ciclo 10322: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 10323: Despachando processo 7 para a CPU (N_CPU: 8).
#
# ** Troca de Contexto no ciclo 10400 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 589/5000 | CP: 590 | Estado: BLOQUEADO | E/S: 8 | N_CPU: 8
#
# --- Ciclo 10400: Despachando processo 2 para a CPU (N_CPU: 11).
#
# ** Troca de Contexto no ciclo 10589 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 1022/7000 | CP: 1023 | Estado: BLOQUEADO | E/S: 11 | N_CPU: 11
#
# --- Evento no ciclo 10589: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 10590: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 10591: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 10592: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 10593: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 10594: Despachando processo 4 para a CPU (N_CPU: 11).
#
# ** Troca de Contexto no ciclo 10969 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 2149/3000 | CP: 2150 | Estado: BLOQUEADO | E/S: 11 | N_CPU: 11
#
# --- Ciclo 10969: Despachando processo 8 para a CPU (N_CPU: 12).
#
# ** Troca de Contexto no ciclo 11003 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 966/4000 | CP: 967 | Estado: BLOQUEADO | E/S: 12 | N_CPU: 12
#
# --- Ciclo 11003: Despachando processo 1 para a CPU (N_CPU: 12).
#
# ** Troca de Contexto no ciclo 11063 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 1424/5000 | CP: 1425 | Estado: BLOQUEADO | E/S: 12 | N_CPU: 12
#
# --- Ciclo 11063: Despachando processo 2 para a CPU (N_CPU: 12).
#
# ** Troca de Contexto no ciclo 11236 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 1195/7000 | CP: 1196 | Estado: BLOQUEADO | E/S: 12 | N_CPU: 12
#
# --- Ciclo 11236: Despachando processo 3 para a CPU (N_CPU: 9).
#
# ** Troca de Contexto no ciclo 11268 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 640/3000 | CP: 641 | Estado: BLOQUEADO | E/S: 9 | N_CPU: 9
#
# --- Evento no ciclo 11268: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 11269: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 11270: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 11271: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 11272: Despachando processo 7 para a CPU (N_CPU: 9).
#
# ** Troca de Contexto no ciclo 11579 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 896/5000 | CP: 897 | Estado: BLOQUEADO | E/S: 9 | N_CPU: 9
#
# --- Ciclo 11579: Despachando processo 8 para a CPU (N_CPU: 13).
#
# ** Troca de Contexto no ciclo 11631 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 1018/4000 | CP: 1019 | Estado: BLOQUEADO | E/S: 13 | N_CPU: 13
#
# --- Evento no ciclo 11631: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 11632: Despachando processo 4 para a CPU (N_CPU: 12).
#
# ** Troca de Contexto no ciclo 11676 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 2193/3000 | CP: 2194 | Estado: BLOQUEADO | E/S: 12 | N_CPU: 12
#
# --- Ciclo 11676: Despachando processo 6 para a CPU (N_CPU: 12).
#
# ** Troca de Contexto no ciclo 11719 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 827/2000 | CP: 828 | Estado: BLOQUEADO | E/S: 12 | N_CPU: 12
#
# --- Evento no ciclo 11719: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 11720: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 11721: Despachando processo 0 para a CPU (N_CPU: 11).
#
# ** Troca de Contexto no ciclo 11727 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 1317/10000 | CP: 1318 | Estado: BLOQUEADO | E/S: 11 | N_CPU: 11
#
# --- Evento no ciclo 11727: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 11728: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 11729: Despachando processo 8 para a CPU (N_CPU: 14).
#
# ** Troca de Contexto no ciclo 11764 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 1053/4000 | CP: 1054 | Estado: BLOQUEADO | E/S: 14 | N_CPU: 14
#
# --- Ciclo 11764: Despachando processo 9 para a CPU (N_CPU: 10).
#
# ** Troca de Contexto no ciclo 11803 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 1196/10000 | CP: 1197 | Estado: BLOQUEADO | E/S: 10 | N_CPU: 10
#
# --- Evento no ciclo 11803: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 11804: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 11805: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 11806: Despachando processo 3 para a CPU (N_CPU: 10).
#
# ** Troca de Contexto no ciclo 11958 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 792/3000 | CP: 793 | Estado: BLOQUEADO | E/S: 10 | N_CPU: 10
#
# --- Ciclo 11958: Despachando processo 4 para a CPU (N_CPU: 13).
#
# ** Troca de Contexto no ciclo 12081 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 2316/3000 | CP: 2317 | Estado: BLOQUEADO | E/S: 13 | N_CPU: 13
#
# --- Evento no ciclo 12081: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 12082: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 12083: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 12084: Despachando processo 0 para a CPU (N_CPU: 12).
#
# ** Troca de Contexto no ciclo 12100 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 1333/10000 | CP: 1334 | Estado: BLOQUEADO | E/S: 12 | N_CPU: 12
#
# --- Ciclo 12100: Despachando processo 1 para a CPU (N_CPU: 13).
#
# ** Troca de Contexto no ciclo 12231 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 1555/5000 | CP: 1556 | Estado: BLOQUEADO | E/S: 13 | N_CPU: 13
#
# --- Ciclo 12231: Despachando processo 2 para a CPU (N_CPU: 13).
#
# ** Troca de Contexto no ciclo 12548 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 1512/7000 | CP: 1513 | Estado: BLOQUEADO | E/S: 13 | N_CPU: 13
#
# --- Evento no ciclo 12548: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 12549: Despachando processo 5 para a CPU (N_CPU: 9).
#
# ** Troca de Contexto no ciclo 12682 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 1094/8000 | CP: 1095 | Estado: BLOQUEADO | E/S: 9 | N_CPU: 9
#
# --- Evento no ciclo 12682: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 12683: Despachando processo 7 para a CPU (N_CPU: 10).
#
# ** Troca de Contexto no ciclo 12710 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 923/5000 | CP: 924 | Estado: BLOQUEADO | E/S: 10 | N_CPU: 10
#
# --- Evento no ciclo 12710: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 12711: Despachando processo 9 para a CPU (N_CPU: 11).
#
# ** Troca de Contexto no ciclo 12766 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 1251/10000 | CP: 1252 | Estado: BLOQUEADO | E/S: 11 | N_CPU: 11
#
# --- Evento no ciclo 12766: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 12767: Despachando processo 3 para a CPU (N_CPU: 11).
#
# ** Troca de Contexto no ciclo 12819 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 844/3000 | CP: 845 | Estado: BLOQUEADO | E/S: 11 | N_CPU: 11
#
# --- Evento no ciclo 12819: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 12820: Despachando processo 6 para a CPU (N_CPU: 13).
#
# ** Troca de Contexto no ciclo 12885 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 892/2000 | CP: 893 | Estado: BLOQUEADO | E/S: 13 | N_CPU: 13
#
# --- Ciclo 12885: Despachando processo 8 para a CPU (N_CPU: 15).
#
# ** Troca de Contexto no ciclo 12929 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 1097/4000 | CP: 1098 | Estado: BLOQUEADO | E/S: 15 | N_CPU: 15
#
# --- Evento no ciclo 12929: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 12930: Despachando processo 2 para a CPU (N_CPU: 14).
#
# ** Troca de Contexto no ciclo 12992 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 1574/7000 | CP: 1575 | Estado: BLOQUEADO | E/S: 14 | N_CPU: 14
#
# --- Ciclo 12992: Despachando processo 4 para a CPU (N_CPU: 14).
#
# ** Troca de Contexto no ciclo 13021 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 2345/3000 | CP: 2346 | Estado: BLOQUEADO | E/S: 14 | N_CPU: 14
#
# --- Evento no ciclo 13021: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 13022: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 13023: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 13024: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 13025: Despachando processo 0 para a CPU (N_CPU: 13).
#
# ** Troca de Contexto no ciclo 13052 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 1360/10000 | CP: 1361 | Estado: BLOQUEADO | E/S: 13 | N_CPU: 13
#
# --- Evento no ciclo 13052: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 13053: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 13054: Despachando processo 5 para a CPU (N_CPU: 10).
#
# ** Troca de Contexto no ciclo 13119 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 1159/8000 | CP: 1160 | Estado: BLOQUEADO | E/S: 10 | N_CPU: 10
#
# --- Ciclo 13119: Despachando processo 6 para a CPU (N_CPU: 14).
#
# ** Troca de Contexto no ciclo 13171 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 944/2000 | CP: 945 | Estado: BLOQUEADO | E/S: 14 | N_CPU: 14
#
# --- Ciclo 13171: Despachando processo 8 para a CPU (N_CPU: 16).
#
# ** Troca de Contexto no ciclo 13173 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 1099/4000 | CP: 1100 | Estado: BLOQUEADO | E/S: 16 | N_CPU: 16
#
# --- Ciclo 13173: Despachando processo 9 para a CPU (N_CPU: 12).
#
# ** Troca de Contexto no ciclo 13396 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 1474/10000 | CP: 1475 | Estado: BLOQUEADO | E/S: 12 | N_CPU: 12
#
# --- Evento no ciclo 13396: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 13397: Despachando processo 3 para a CPU (N_CPU: 12).
#
# ** Troca de Contexto no ciclo 13614 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 1061/3000 | CP: 1062 | Estado: BLOQUEADO | E/S: 12 | N_CPU: 12
#
# --- Ciclo 13614: Despachando processo 4 para a CPU (N_CPU: 15).
#
# ** Troca de Contexto no ciclo 13789 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 2520/3000 | CP: 2521 | Estado: BLOQUEADO | E/S: 15 | N_CPU: 15
#
# --- Ciclo 13789: Despachando processo 2 para a CPU (N_CPU: 15).
#
# ** Troca de Contexto no ciclo 13866 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 1651/7000 | CP: 1652 | Estado: BLOQUEADO | E/S: 15 | N_CPU: 15
#
# --- Evento no ciclo 13866: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 13867: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 13868: Despachando processo 3 para a CPU (N_CPU: 13).
#
# ** Troca de Contexto no ciclo 13988 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 1181/3000 | CP: 1182 | Estado: BLOQUEADO | E/S: 13 | N_CPU: 13
#
# --- Evento no ciclo 13988: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 13989: Despachando processo 5 para a CPU (N_CPU: 11).
#
# ** Troca de Contexto no ciclo 14026 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 1196/8000 | CP: 1197 | Estado: BLOQUEADO | E/S: 11 | N_CPU: 11
#
# --- Evento no ciclo 14026: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 14027: Despachando processo 4 para a CPU (N_CPU: 16).
#
# ** Troca de Contexto no ciclo 14034 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 2527/3000 | CP: 2528 | Estado: BLOQUEADO | E/S: 16 | N_CPU: 16
#
# --- Evento no ciclo 14034: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 14035: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 14036: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 14037: Despachando processo 0 para a CPU (N_CPU: 14).
#
# ** Troca de Contexto no ciclo 14107 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 1430/10000 | CP: 1431 | Estado: BLOQUEADO | E/S: 14 | N_CPU: 14
#
# --- Evento no ciclo 14107: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 14108: Despachando processo 7 para a CPU (N_CPU: 11).
#
# ** Troca de Contexto no ciclo 14182 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 997/5000 | CP: 998 | Estado: BLOQUEADO | E/S: 11 | N_CPU: 11
#
# --- Ciclo 14182: Despachando processo 8 para a CPU (N_CPU: 17).
#
# ** Troca de Contexto no ciclo 14219 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 1136/4000 | CP: 1137 | Estado: BLOQUEADO | E/S: 17 | N_CPU: 17
#
# --- Ciclo 14219: Despachando processo 9 para a CPU (N_CPU: 13).
#
# ** Troca de Contexto no ciclo 14385 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 1640/10000 | CP: 1641 | Estado: BLOQUEADO | E/S: 13 | N_CPU: 13
#
# --- Ciclo 14385: Despachando processo 4 para a CPU (N_CPU: 17).
#
# ** Troca de Contexto no ciclo 14452 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 2594/3000 | CP: 2595 | Estado: BLOQUEADO | E/S: 17 | N_CPU: 17
#
# --- Evento no ciclo 14452: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 14453: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 14454: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 14455: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 14456: Despachando processo 7 para a CPU (N_CPU: 12).
#
# ** Troca de Contexto no ciclo 14588 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 1129/5000 | CP: 1130 | Estado: BLOQUEADO | E/S: 12 | N_CPU: 12
#
# --- Ciclo 14588: Despachando processo 9 para a CPU (N_CPU: 14).
#
# ** Troca de Contexto no ciclo 14707 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 1759/10000 | CP: 1760 | Estado: BLOQUEADO | E/S: 14 | N_CPU: 14
#
# --- Ciclo 14707: Despachando processo 1 para a CPU (N_CPU: 14).
#
# ** Troca de Contexto no ciclo 14779 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 1627/5000 | CP: 1628 | Estado: BLOQUEADO | E/S: 14 | N_CPU: 14
#
# --- Ciclo 14779: Despachando processo 3 para a CPU (N_CPU: 14).
#
# ** Troca de Contexto no ciclo 15069 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 1471/3000 | CP: 1472 | Estado: BLOQUEADO | E/S: 14 | N_CPU: 14
#
# --- Evento no ciclo 15069: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 15070: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 15071: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 15072: Processo 1 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 15073: Processo 3 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 15074: Despachando processo 6 para a CPU (N_CPU: 15).
#
# ** Troca de Contexto no ciclo 15362 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 1232/2000 | CP: 1233 | Estado: BLOQUEADO | E/S: 15 | N_CPU: 15
#
# --- Evento no ciclo 15362: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 15363: Despachando processo 8 para a CPU (N_CPU: 18).
#
# ** Troca de Contexto no ciclo 15889 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 1662/4000 | CP: 1663 | Estado: BLOQUEADO | E/S: 18 | N_CPU: 18
#
# --- Evento no ciclo 15889: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 15890: Despachando processo 0 para a CPU (N_CPU: 15).
#
# ** Troca de Contexto no ciclo 15930 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 1470/10000 | CP: 1471 | Estado: BLOQUEADO | E/S: 15 | N_CPU: 15
#
# --- Ciclo 15930: Despachando processo 1 para a CPU (N_CPU: 15).
#
# ** Troca de Contexto no ciclo 16092 **
#    Processo 1: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 1 | TP: 1789/5000 | CP: 1790 | Estado: BLOQUEADO | E/S: 15 | N_CPU: 15
#
# --- Ciclo 16092: Despachando processo 3 para a CPU (N_CPU: 15).
#
# ** Troca de Contexto no ciclo 16138 **
#    Processo 3: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 3 | TP: 1517/3000 | CP: 1518 | Estado: BLOQUEADO | E/S: 15 | N_CPU: 15
#
# --- Evento no ciclo 16138: Processo 4 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 16139: Processo 6 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 16140: Despachando processo 7 para a CPU (N_CPU: 13).
#
# ** Troca de Contexto no ciclo 16228 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 1217/5000 | CP: 1218 | Estado: BLOQUEADO | E/S: 13 | N_CPU: 13
#
# --- Ciclo 16228: Despachando processo 9 para a CPU (N_CPU: 15).
#
# ** Troca de Contexto no ciclo 16514 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 2045/10000 | CP: 2046 | Estado: BLOQUEADO | E/S: 15 | N_CPU: 15
#
# --- Ciclo 16514: Despachando processo 4 para a CPU (N_CPU: 18).
#
# ** Troca de Contexto no ciclo 16680 **
#    Processo 4: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 4 | TP: 2760/3000 | CP: 2761 | Estado: BLOQUEADO | E/S: 18 | N_CPU: 18
#
# --- Ciclo 16680: Despachando processo 6 para a CPU (N_CPU: 16).
#
# ** Troca de Contexto no ciclo 16919 **
#    Processo 6: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 6 | TP: 1471/2000 | CP: 1472 | Estado: BLOQUEADO | E/S: 16 | N_CPU: 16
#
# --- Evento no ciclo 16919: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 16920: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 16921: Processo 2 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 16922: Despachando processo 7 para a CPU (N_CPU: 14).
#
# ** Troca de Contexto no ciclo 17056 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 1351/5000 | CP: 1352 | Estado: BLOQUEADO | E/S: 14 | N_CPU: 14
#
# --- Ciclo 17056: Despachando processo 8 para a CPU (N_CPU: 19).
#
# ** Troca de Contexto no ciclo 17211 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 1817/4000 | CP: 1818 | Estado: BLOQUEADO | E/S: 19 | N_CPU: 19
#
# --- Ciclo 17211: Despachando processo 2 para a CPU (N_CPU: 16).
#
# ** Troca de Contexto no ciclo 17219 **
#    Processo 2: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 2 | TP: 1659/7000 | CP: 1660 | Estado: BLOQUEADO | E/S: 16 | N_CPU: 16
#
# --- Evento no ciclo 17219: Processo 7 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 17220: Processo 8 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 17221: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 17222: Despachando processo 7 para a CPU (N_CPU: 15).
#
# ** Troca de Contexto no ciclo 17391 **
#    Processo 7: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 7 | TP: 1520/5000 | CP: 1521 | Estado: BLOQUEADO | E/S: 15 | N_CPU: 15
#
# --- Ciclo 17391: Despachando processo 8 para a CPU (N_CPU: 20).
#
# ** Troca de Contexto no ciclo 17419 **
#    Processo 8: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 8 | TP: 1845/4000 | CP: 1846 | Estado: BLOQUEADO | E/S: 20 | N_CPU: 20
#
# --- Ciclo 17419: Despachando processo 9 para a CPU (N_CPU: 16).
#
# ** Troca de Contexto no ciclo 17575 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 2201/10000 | CP: 2202 | Estado: BLOQUEADO | E/S: 16 | N_CPU: 16
#
# ...
#
# ** Troca de Contexto no ciclo 52116 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 7211/10000 | CP: 7212 | Estado: BLOQUEADO | E/S: 82 | N_CPU: 82
#
# --- Evento no ciclo 52116: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 52117: Despachando processo 9 para a CPU (N_CPU: 74).
#
# ** Troca de Contexto no ciclo 52187 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 9209/10000 | CP: 9210 | Estado: BLOQUEADO | E/S: 74 | N_CPU: 74
#
# --- Evento no ciclo 52187: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 52188: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 52189: Despachando processo 0 para a CPU (N_CPU: 83).
#
# ** Troca de Contexto no ciclo 52192 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 7214/10000 | CP: 7215 | Estado: BLOQUEADO | E/S: 83 | N_CPU: 83
#
# --- Ciclo 52192: Despachando processo 5 para a CPU (N_CPU: 76).
#
# ** Troca de Contexto no ciclo 52306 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 6370/8000 | CP: 6371 | Estado: BLOQUEADO | E/S: 76 | N_CPU: 76
#
# --- Evento no ciclo 52306: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 52307: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 52308: Despachando processo 9 para a CPU (N_CPU: 75).
#
# ** Troca de Contexto no ciclo 52370 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 9271/10000 | CP: 9272 | Estado: BLOQUEADO | E/S: 75 | N_CPU: 75
#
# --- Ciclo 52370: Despachando processo 0 para a CPU (N_CPU: 84).
#
# ** Troca de Contexto no ciclo 52602 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 7446/10000 | CP: 7447 | Estado: BLOQUEADO | E/S: 84 | N_CPU: 84
#
# --- Evento no ciclo 52602: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 52603: Despachando processo 5 para a CPU (N_CPU: 77).
#
# ** Troca de Contexto no ciclo 52608 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 6375/8000 | CP: 6376 | Estado: BLOQUEADO | E/S: 77 | N_CPU: 77
#
# --- Evento no ciclo 52608: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 52609: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 52610: Despachando processo 0 para a CPU (N_CPU: 85).
#
# ** Troca de Contexto no ciclo 52829 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 7665/10000 | CP: 7666 | Estado: BLOQUEADO | E/S: 85 | N_CPU: 85
#
# --- Ciclo 52829: Despachando processo 5 para a CPU (N_CPU: 78).
#
# ** Troca de Contexto no ciclo 53066 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 6612/8000 | CP: 6613 | Estado: BLOQUEADO | E/S: 78 | N_CPU: 78
#
# --- Evento no ciclo 53066: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 53067: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 53068: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 53069: Despachando processo 9 para a CPU (N_CPU: 76).
#
# ** Troca de Contexto no ciclo 53215 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 9417/10000 | CP: 9418 | Estado: BLOQUEADO | E/S: 76 | N_CPU: 76
#
# --- Ciclo 53215: Despachando processo 0 para a CPU (N_CPU: 86).
#
# ** Troca de Contexto no ciclo 53652 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 8102/10000 | CP: 8103 | Estado: BLOQUEADO | E/S: 86 | N_CPU: 86
#
# --- Ciclo 53652: Despachando processo 5 para a CPU (N_CPU: 79).
#
# ** Troca de Contexto no ciclo 53667 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 6627/8000 | CP: 6628 | Estado: BLOQUEADO | E/S: 79 | N_CPU: 79
#
# --- Evento no ciclo 53667: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 53668: Despachando processo 0 para a CPU (N_CPU: 87).
#
# ** Troca de Contexto no ciclo 53676 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 8110/10000 | CP: 8111 | Estado: BLOQUEADO | E/S: 87 | N_CPU: 87
#
# --- Evento no ciclo 53676: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 53677: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 53678: Despachando processo 9 para a CPU (N_CPU: 77).
#
# ** Troca de Contexto no ciclo 53937 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 9676/10000 | CP: 9677 | Estado: BLOQUEADO | E/S: 77 | N_CPU: 77
#
# --- Evento no ciclo 53937: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 53938: Despachando processo 5 para a CPU (N_CPU: 80).
#
# ** Troca de Contexto no ciclo 54052 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 6741/8000 | CP: 6742 | Estado: BLOQUEADO | E/S: 80 | N_CPU: 80
#
# --- Evento no ciclo 54052: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 54053: Despachando processo 0 para a CPU (N_CPU: 88).
#
# ** Troca de Contexto no ciclo 54275 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 8332/10000 | CP: 8333 | Estado: BLOQUEADO | E/S: 88 | N_CPU: 88
#
# --- Ciclo 54275: Despachando processo 9 para a CPU (N_CPU: 78).
#
# ** Troca de Contexto no ciclo 54301 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 9702/10000 | CP: 9703 | Estado: BLOQUEADO | E/S: 78 | N_CPU: 78
#
# --- Evento no ciclo 54301: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 54302: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 54303: Despachando processo 5 para a CPU (N_CPU: 81).
#
# ** Troca de Contexto no ciclo 54434 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 6872/8000 | CP: 6873 | Estado: BLOQUEADO | E/S: 81 | N_CPU: 81
#
# --- Ciclo 54434: Despachando processo 0 para a CPU (N_CPU: 89).
#
# ** Troca de Contexto no ciclo 54479 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 8377/10000 | CP: 8378 | Estado: BLOQUEADO | E/S: 89 | N_CPU: 89
#
# --- Evento no ciclo 54479: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 54480: Despachando processo 5 para a CPU (N_CPU: 82).
#
# ** Troca de Contexto no ciclo 54516 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 6908/8000 | CP: 6909 | Estado: BLOQUEADO | E/S: 82 | N_CPU: 82
#
# --- Evento no ciclo 54516: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 54517: Despachando processo 9 para a CPU (N_CPU: 79).
#
# ** Troca de Contexto no ciclo 54568 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 9753/10000 | CP: 9754 | Estado: BLOQUEADO | E/S: 79 | N_CPU: 79
#
# --- Evento no ciclo 54568: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 54569: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 54570: Despachando processo 5 para a CPU (N_CPU: 83).
#
# ** Troca de Contexto no ciclo 54573 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 6911/8000 | CP: 6912 | Estado: BLOQUEADO | E/S: 83 | N_CPU: 83
#
# --- Ciclo 54573: Despachando processo 0 para a CPU (N_CPU: 90).
#
# ** Troca de Contexto no ciclo 54676 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 8480/10000 | CP: 8481 | Estado: BLOQUEADO | E/S: 90 | N_CPU: 90
#
# --- Evento no ciclo 54676: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 54677: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 54678: Despachando processo 0 para a CPU (N_CPU: 91).
#
# ** Troca de Contexto no ciclo 54777 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 8579/10000 | CP: 8580 | Estado: BLOQUEADO | E/S: 91 | N_CPU: 91
#
# --- Ciclo 54777: Despachando processo 5 para a CPU (N_CPU: 84).
#
# ** Troca de Contexto no ciclo 55117 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 7251/8000 | CP: 7252 | Estado: BLOQUEADO | E/S: 84 | N_CPU: 84
#
# --- Evento no ciclo 55117: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 55118: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 55119: Despachando processo 9 para a CPU (N_CPU: 80).
#
# ** Troca de Contexto no ciclo 55261 **
#    Processo 9: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 9 | TP: 9895/10000 | CP: 9896 | Estado: BLOQUEADO | E/S: 80 | N_CPU: 80
#
# --- Ciclo 55261: Despachando processo 0 para a CPU (N_CPU: 92).
#
# ** Troca de Contexto no ciclo 55349 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 8667/10000 | CP: 8668 | Estado: BLOQUEADO | E/S: 92 | N_CPU: 92
#
# --- Evento no ciclo 55349: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 55350: Despachando processo 5 para a CPU (N_CPU: 85).
#
# ** Troca de Contexto no ciclo 55480 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 7381/8000 | CP: 7382 | Estado: BLOQUEADO | E/S: 85 | N_CPU: 85
#
# --- Evento no ciclo 55480: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 55481: Despachando processo 5 para a CPU (N_CPU: 86).
#
# ** Troca de Contexto no ciclo 55561 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 7461/8000 | CP: 7462 | Estado: BLOQUEADO | E/S: 86 | N_CPU: 86
#
# --- Evento no ciclo 55561: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Evento no ciclo 55562: Processo 9 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 55563: Despachando processo 5 para a CPU (N_CPU: 87).
#
# ** Troca de Contexto no ciclo 55843 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 7741/8000 | CP: 7742 | Estado: BLOQUEADO | E/S: 87 | N_CPU: 87
#
# --- Ciclo 55843: Despachando processo 9 para a CPU (N_CPU: 81).
#
# ==================================================
# PROCESSO 9 TERMINOU NO CICLO 55948
# Estado Final: PID: 9 | TP: 10000/10000 | CP: 10001 | Estado: TERMINADO | E/S: 80 | N_CPU: 81
# ==================================================
#
# --- Evento no ciclo 55948: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 55949: Despachando processo 5 para a CPU (N_CPU: 88).
#
# ** Troca de Contexto no ciclo 56087 **
#    Processo 5: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 5 | TP: 7879/8000 | CP: 7880 | Estado: BLOQUEADO | E/S: 88 | N_CPU: 88
#
# --- Evento no ciclo 56087: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 56088: Despachando processo 0 para a CPU (N_CPU: 93).
#
# ** Troca de Contexto no ciclo 56146 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 8725/10000 | CP: 8726 | Estado: BLOQUEADO | E/S: 93 | N_CPU: 93
#
# --- Evento no ciclo 56146: Processo 5 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 56147: Despachando processo 5 para a CPU (N_CPU: 89).
#
# ==================================================
# PROCESSO 5 TERMINOU NO CICLO 56268
# Estado Final: PID: 5 | TP: 8000/8000 | CP: 8001 | Estado: TERMINADO | E/S: 88 | N_CPU: 89
# ==================================================
#
# --- Evento no ciclo 56268: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 56269: Despachando processo 0 para a CPU (N_CPU: 94).
#
# ** Troca de Contexto no ciclo 56347 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 8803/10000 | CP: 8804 | Estado: BLOQUEADO | E/S: 94 | N_CPU: 94
#
# --- Evento no ciclo 56347: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 56348: Despachando processo 0 para a CPU (N_CPU: 95).
#
# ** Troca de Contexto no ciclo 56514 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 8969/10000 | CP: 8970 | Estado: BLOQUEADO | E/S: 95 | N_CPU: 95
#
# --- Evento no ciclo 56514: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 56515: Despachando processo 0 para a CPU (N_CPU: 96).
#
# ** Troca de Contexto no ciclo 56567 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9021/10000 | CP: 9022 | Estado: BLOQUEADO | E/S: 96 | N_CPU: 96
#
# --- Evento no ciclo 56567: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 56568: Despachando processo 0 para a CPU (N_CPU: 97).
#
# ** Troca de Contexto no ciclo 56651 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9104/10000 | CP: 9105 | Estado: BLOQUEADO | E/S: 97 | N_CPU: 97
#
# --- Evento no ciclo 56651: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 56652: Despachando processo 0 para a CPU (N_CPU: 98).
#
# ** Troca de Contexto no ciclo 56771 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9223/10000 | CP: 9224 | Estado: BLOQUEADO | E/S: 98 | N_CPU: 98
#
# --- Evento no ciclo 56771: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 56772: Despachando processo 0 para a CPU (N_CPU: 99).
#
# ** Troca de Contexto no ciclo 56889 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9340/10000 | CP: 9341 | Estado: BLOQUEADO | E/S: 99 | N_CPU: 99
#
# --- Evento no ciclo 56889: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 56890: Despachando processo 0 para a CPU (N_CPU: 100).
#
# ** Troca de Contexto no ciclo 56950 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9400/10000 | CP: 9401 | Estado: BLOQUEADO | E/S: 100 | N_CPU: 100
#
# --- Evento no ciclo 56950: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 56951: Despachando processo 0 para a CPU (N_CPU: 101).
#
# ** Troca de Contexto no ciclo 56989 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9438/10000 | CP: 9439 | Estado: BLOQUEADO | E/S: 101 | N_CPU: 101
#
# --- Evento no ciclo 56989: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 56990: Despachando processo 0 para a CPU (N_CPU: 102).
#
# ** Troca de Contexto no ciclo 57106 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9554/10000 | CP: 9555 | Estado: BLOQUEADO | E/S: 102 | N_CPU: 102
#
# --- Evento no ciclo 57106: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 57107: Despachando processo 0 para a CPU (N_CPU: 103).
#
# ** Troca de Contexto no ciclo 57126 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9573/10000 | CP: 9574 | Estado: BLOQUEADO | E/S: 103 | N_CPU: 103
#
# --- Evento no ciclo 57126: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 57127: Despachando processo 0 para a CPU (N_CPU: 104).
#
# ** Troca de Contexto no ciclo 57232 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9678/10000 | CP: 9679 | Estado: BLOQUEADO | E/S: 104 | N_CPU: 104
#
# --- Evento no ciclo 57232: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 57233: Despachando processo 0 para a CPU (N_CPU: 105).
#
# ** Troca de Contexto no ciclo 57326 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9771/10000 | CP: 9772 | Estado: BLOQUEADO | E/S: 105 | N_CPU: 105
#
# --- Evento no ciclo 57326: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 57327: Despachando processo 0 para a CPU (N_CPU: 106).
#
# ** Troca de Contexto no ciclo 57341 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9785/10000 | CP: 9786 | Estado: BLOQUEADO | E/S: 106 | N_CPU: 106
#
# --- Evento no ciclo 57341: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 57342: Despachando processo 0 para a CPU (N_CPU: 107).
#
# ** Troca de Contexto no ciclo 57373 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9816/10000 | CP: 9817 | Estado: BLOQUEADO | E/S: 107 | N_CPU: 107
#
# --- Evento no ciclo 57373: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 57374: Despachando processo 0 para a CPU (N_CPU: 108).
#
# ** Troca de Contexto no ciclo 57485 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9927/10000 | CP: 9928 | Estado: BLOQUEADO | E/S: 108 | N_CPU: 108
#
# --- Evento no ciclo 57485: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 57486: Despachando processo 0 para a CPU (N_CPU: 109).
#
# ** Troca de Contexto no ciclo 57499 **
#    Processo 0: EXECUTANDO >>> BLOQUEADO
#    Estado salvo: PID: 0 | TP: 9940/10000 | CP: 9941 | Estado: BLOQUEADO | E/S: 109 | N_CPU: 109
#
# --- Evento no ciclo 57499: Processo 0 desbloqueado. Agora está PRONTO.
#
# --- Ciclo 57500: Despachando processo 0 para a CPU (N_CPU: 110).
#
# ==================================================
# PROCESSO 0 TERMINOU NO CICLO 57560
# Estado Final: PID: 0 | TP: 10000/10000 | CP: 10001 | Estado: TERMINADO | E/S: 109 | N_CPU: 110
# ==================================================
#
# >>> FIM DA SIMULAÇÃO: Todos os processos foram concluídos. <<<
